# %% [markdown]
# ## EDA to prediction (titanic)
#
# - 캐글 원본
# https://www.kaggle.com/ash316/eda-to-prediction-dietanic#Ensembling
#
# - 티스토리(한국어)
# https://injo.tistory.com/19#Confusion-Matrix

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
import warnings
warnings.filterwarnings('ignore')
sns.set(font_scale=2)

# %%
# 데이터 불러오기, 데이터 확인 
data = pd.read_csv("../data/titanic.csv")
data.head() 
data.tail() #PassengerID가 891인거 보면 891명이 타고 있었음을 알 수 있다.
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# 결측치 확인(자주사용)
data.isnull().sum(axis=0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## How many Survived?

# %%
f,ax=plt.subplots(1,2,figsize = (18,8))
#1=log의 개수 2=culumn의 개수 캔버스만드는 과정
data['Survived'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.3f%%', ax=ax[0])
#value_counts()는 null value 반환x
#explode 그래프 사이 거리조절
#autopct 소수점 1.3 셋째자리
#ax=ax[0] 왼쪽에 그래프 그리기
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=data, ax=ax[1])
ax[1].set_title('Survived')
#ax[1].set_ylabel('')
plt.show()

# %% [markdown]
# 0 : Survived , 1 : Dead
#
# 891명의 passenger중에 대략 350명, 38.4% 만 살았다는 것을 알 수 있다.
#
# Age, Pclass..등 feature 에 따라 생존률에 영향을 주었는지 확인하기 위해 Feature들의 타입을 확인한다.

# %% [markdown]
# ## Types Of Features
# - Categorical Features : Sex, Embarked 순서 상관 없는 것
# - Ordinal Features : PClass 서열,순서가 있는 것
# - Continuous Feature : Age

# %%
# 성별에 따른 생존률 확인
data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
data[['Sex','Survived']].groupby(['Sex']).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
f, ax = plt.subplots(1,2,figsize = (18,8))
data[['Sex', 'Survived']].groupby(['Sex']).mean().plot.bar(ax = ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue = 'Survived', data = data, ax = ax[1])
ax[1].set_title('Sex : Survived vs Dead')
plt.show()

# %% [markdown]
# 탑승자는 남자가 많지만 생존자는 여자가 더 많은 것을 볼 수 있다. 여자의 생존률은 약 75%, 남자는 18%정도이다.

# %%
# 좌석 class 별 생존률 확인해보자
pd.crosstab(data.Pclass, data.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_45207676_bddf_11eb_a413_7c04d0c2b56erow0_col0,#T_45207676_bddf_11eb_a413_7c04d0c2b56erow1_col1,#T_45207676_bddf_11eb_a413_7c04d0c2b56erow1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_45207676_bddf_11eb_a413_7c04d0c2b56erow0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_45207676_bddf_11eb_a413_7c04d0c2b56erow0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_45207676_bddf_11eb_a413_7c04d0c2b56erow1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_45207676_bddf_11eb_a413_7c04d0c2b56erow2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_45207676_bddf_11eb_a413_7c04d0c2b56erow2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_45207676_bddf_11eb_a413_7c04d0c2b56erow2_col2{
#             background-color:  #90c866;
#             color:  #000000;
#         }#T_45207676_bddf_11eb_a413_7c04d0c2b56erow3_col0,#T_45207676_bddf_11eb_a413_7c04d0c2b56erow3_col1,#T_45207676_bddf_11eb_a413_7c04d0c2b56erow3_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_45207676_bddf_11eb_a413_7c04d0c2b56e" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45207676_bddf_11eb_a413_7c04d0c2b56elevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_45207676_bddf_11eb_a413_7c04d0c2b56erow0_col0" class="data row0 col0" >80</td>
#                         <td id="T_45207676_bddf_11eb_a413_7c04d0c2b56erow0_col1" class="data row0 col1" >136</td>
#                         <td id="T_45207676_bddf_11eb_a413_7c04d0c2b56erow0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_45207676_bddf_11eb_a413_7c04d0c2b56elevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_45207676_bddf_11eb_a413_7c04d0c2b56erow1_col0" class="data row1 col0" >97</td>
#                         <td id="T_45207676_bddf_11eb_a413_7c04d0c2b56erow1_col1" class="data row1 col1" >87</td>
#                         <td id="T_45207676_bddf_11eb_a413_7c04d0c2b56erow1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_45207676_bddf_11eb_a413_7c04d0c2b56elevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_45207676_bddf_11eb_a413_7c04d0c2b56erow2_col0" class="data row2 col0" >372</td>
#                         <td id="T_45207676_bddf_11eb_a413_7c04d0c2b56erow2_col1" class="data row2 col1" >119</td>
#                         <td id="T_45207676_bddf_11eb_a413_7c04d0c2b56erow2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_45207676_bddf_11eb_a413_7c04d0c2b56elevel0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_45207676_bddf_11eb_a413_7c04d0c2b56erow3_col0" class="data row3 col0" >549</td>
#                         <td id="T_45207676_bddf_11eb_a413_7c04d0c2b56erow3_col1" class="data row3 col1" >342</td>
#                         <td id="T_45207676_bddf_11eb_a413_7c04d0c2b56erow3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f,ax = plt.subplots(1, 2, figsize = (18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32', '#FFDF10', '#809fff'], ax = ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue = 'Survived', data = data, ax = ax[1])
ax[1].set_title('Pclass : Survived vs Dead')
plt.show()

# %% [markdown]
# Pclass 1 > 2 > 3 (등급순)
#
# Pclass 3의 탑승인원이 가장 많지만 생존률이 낮은 것을 볼 수 있다. 반면 Pclass 1의 생존률은 매우 높은 것을 확인 할 수 있다.

# %%
# survival rate, sex, Pclass 간의 관계를 알아보자.
pd.crosstab([data['Sex'], data['Survived']], data['Pclass'], margins = True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_45681742_bddf_11eb_a413_7c04d0c2b56erow0_col0,#T_45681742_bddf_11eb_a413_7c04d0c2b56erow0_col1,#T_45681742_bddf_11eb_a413_7c04d0c2b56erow0_col3,#T_45681742_bddf_11eb_a413_7c04d0c2b56erow3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_45681742_bddf_11eb_a413_7c04d0c2b56erow0_col2,#T_45681742_bddf_11eb_a413_7c04d0c2b56erow1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_45681742_bddf_11eb_a413_7c04d0c2b56erow1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_45681742_bddf_11eb_a413_7c04d0c2b56erow1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_45681742_bddf_11eb_a413_7c04d0c2b56erow1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_45681742_bddf_11eb_a413_7c04d0c2b56erow2_col0{
#             background-color:  #a7d366;
#             color:  #000000;
#         }#T_45681742_bddf_11eb_a413_7c04d0c2b56erow2_col1,#T_45681742_bddf_11eb_a413_7c04d0c2b56erow2_col3{
#             background-color:  #85c266;
#             color:  #000000;
#         }#T_45681742_bddf_11eb_a413_7c04d0c2b56erow2_col2{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_45681742_bddf_11eb_a413_7c04d0c2b56erow3_col0{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_45681742_bddf_11eb_a413_7c04d0c2b56erow3_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_45681742_bddf_11eb_a413_7c04d0c2b56erow3_col3{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_45681742_bddf_11eb_a413_7c04d0c2b56erow4_col0,#T_45681742_bddf_11eb_a413_7c04d0c2b56erow4_col1,#T_45681742_bddf_11eb_a413_7c04d0c2b56erow4_col2,#T_45681742_bddf_11eb_a413_7c04d0c2b56erow4_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_45681742_bddf_11eb_a413_7c04d0c2b56e" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45681742_bddf_11eb_a413_7c04d0c2b56elevel0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_45681742_bddf_11eb_a413_7c04d0c2b56elevel1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow0_col0" class="data row0 col0" >3</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow0_col1" class="data row0 col1" >6</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow0_col2" class="data row0 col2" >72</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_45681742_bddf_11eb_a413_7c04d0c2b56elevel1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow1_col0" class="data row1 col0" >91</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow1_col1" class="data row1 col1" >70</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow1_col2" class="data row1 col2" >72</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_45681742_bddf_11eb_a413_7c04d0c2b56elevel0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_45681742_bddf_11eb_a413_7c04d0c2b56elevel1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow2_col0" class="data row2 col0" >77</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow2_col1" class="data row2 col1" >91</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow2_col2" class="data row2 col2" >300</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_45681742_bddf_11eb_a413_7c04d0c2b56elevel1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow3_col0" class="data row3 col0" >45</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow3_col1" class="data row3 col1" >17</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow3_col2" class="data row3 col2" >47</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_45681742_bddf_11eb_a413_7c04d0c2b56elevel0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_45681742_bddf_11eb_a413_7c04d0c2b56elevel1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow4_col0" class="data row4 col0" >216</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow4_col1" class="data row4 col1" >184</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow4_col2" class="data row4 col2" >491</td>
#                         <td id="T_45681742_bddf_11eb_a413_7c04d0c2b56erow4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Pclass', 'Survived', hue = 'Sex', data = data)

# %% [markdown]
# Categorical value(성별, 그룹 등 순서에 의미가 없는 것)는 FactorPlot 사용. 한눈에 보기 쉬움
#
# Pclass 1 여성은 90% 이상의 확률로 생존했다.

# %%
print('Oldest Passenger was of:', data['Age'].max(),'Years')
print('Youngest PAssenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:', data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest PAssenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
data['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.kdeplot(data.loc[data['Survived']==1, 'Age'], label = 'Survived') #파란선
sns.kdeplot(data.loc[data['Survived']==0, 'Age'], label = 'Died') #주황선
plt.xlabel('Age')
plt.ylabel('count')
plt.legend()

# %%
data['Age'].hist()
plt.xlabel('Age')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
f,ax = plt.subplots(1, 2, figsize = (18,8))
sns.violinplot("Pclass", "Age", hue = 'Survived', data = data, split = True, ax = ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))
# yticks : 새로에 있는 수자 범위 0부터 10씩 증가 
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# 1. Pclass 에 관계없이 10세 이하의 Age는 생존률이 높다.
# 2. Pcalss1 에서 20-50세 생존률이 높고, 여성에서 높게 나타난다.
#
# Age 변수에 177개의 값이 비어있다. 이 값을 평균 나이인 29새로 하는 것은 문제가 생긴다. (3살인데 29세라고 하면 정확한 에측이 어려움)
#
# 따라서 승객의 연령대를 알기위해 Mr, Mrs, 각 그룹의 평균 나이를 알아보자.

# %%
data['Initial'] = 0
for i in data :
    data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(data.Initial, data.Sex).T.style.background_gradient(cmap = 'summer_r')
# T -> transpose 행렬 위치 바꿔줌
# Out:
# <style  type="text/css" >
# #T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col0,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col1,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col3,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col4,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col5,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col7,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col8,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col12,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col15,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col16,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col2,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col6,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col9,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col10,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col11,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col13,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col14{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col2,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col6,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col9,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col10,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col11,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col13,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col14,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col0,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col1,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col3,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col4,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col5,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col7,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col8,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col12,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col15,#T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col16{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56e" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56elevel0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col2" class="data row0 col2" >1</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col3" class="data row0 col3" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col4" class="data row0 col4" >1</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col5" class="data row0 col5" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col6" class="data row0 col6" >1</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col7" class="data row0 col7" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col8" class="data row0 col8" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col9" class="data row0 col9" >182</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col10" class="data row0 col10" >2</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col11" class="data row0 col11" >1</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col12" class="data row0 col12" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col13" class="data row0 col13" >125</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col14" class="data row0 col14" >1</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col15" class="data row0 col15" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow0_col16" class="data row0 col16" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56elevel0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col1" class="data row1 col1" >2</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col2" class="data row1 col2" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col4" class="data row1 col4" >6</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col5" class="data row1 col5" >1</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col6" class="data row1 col6" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col7" class="data row1 col7" >2</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col8" class="data row1 col8" >40</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col9" class="data row1 col9" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col10" class="data row1 col10" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col11" class="data row1 col11" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col12" class="data row1 col12" >517</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col13" class="data row1 col13" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col14" class="data row1 col14" >0</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col15" class="data row1 col15" >6</td>
#                         <td id="T_46ea9ac2_bddf_11eb_a413_7c04d0c2b56erow1_col16" class="data row1 col16" >1</td>
#             </tr>
#     </tbody></table>

# %%
# 잘못 써진 이름 Mr, Mrs로 바꾸는 과정 
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don']
                       ,['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
# 이름 바꼈나 확인 
data.loc[1:,:]
data.iloc[:,:4]
# loc 행 선택 [3:10,:] -> 3행부터 10행까지 출력
# iloc 열 선택 [:,:3] -> 3열까지 출력
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 4 columns]

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Initial          0
# dtype: int64

# %%
# NULL인 Age에 각 그룹 별 평균 나이로 바꿔주자
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.Age.isnull().any()
# Out:
# False

# %%
f,ax = plt.subplots(1, 2, figsize = (20,10))
data.loc[data['Survived']==0].Age.plot.hist(ax = ax[0], bins = 20, edgecolor = 'black', color = 'red')
ax[0].set_title('Survived=0')
ax[0].set_xticks(range(0, 85, 5))
data.loc[data['Survived']==1].Age.plot.hist(ax = ax[1], bins = 20, edgecolor = 'black', color = 'green')
ax[1].set_title('Survived=1')
ax[1].set_xticks(range(0, 85, 5))
# Out:
# [<matplotlib.axis.XTick at 0x7f9a5bdb8e10>,
#  <matplotlib.axis.XTick at 0x7f9a5bdb3cd0>,
#  <matplotlib.axis.XTick at 0x7f9a5d3dddd0>,
#  <matplotlib.axis.XTick at 0x7f9a5d419ad0>,
#  <matplotlib.axis.XTick at 0x7f9a5d424050>,
#  <matplotlib.axis.XTick at 0x7f9a5d4241d0>,
#  <matplotlib.axis.XTick at 0x7f9a5d424b50>,
#  <matplotlib.axis.XTick at 0x7f9a5bde2890>,
#  <matplotlib.axis.XTick at 0x7f9a5d42b210>,
#  <matplotlib.axis.XTick at 0x7f9a5d42b9d0>,
#  <matplotlib.axis.XTick at 0x7f9a5d424c50>,
#  <matplotlib.axis.XTick at 0x7f9a5d42bcd0>,
#  <matplotlib.axis.XTick at 0x7f9a5d42bc50>,
#  <matplotlib.axis.XTick at 0x7f9a5d433290>,
#  <matplotlib.axis.XTick at 0x7f9a5d433310>,
#  <matplotlib.axis.XTick at 0x7f9a5d433ed0>,
#  <matplotlib.axis.XTick at 0x7f9a5d43d290>]

# %% [markdown]
# 1. 5세 이하 아이들은 많이 구조되었다.
# 2. 가장 나이 많은 승객은 구조되었다.
# 3. 가장 많이 사망한 연령대는 30-40대 이다.

# %%
# Pclass에 따른 생존률을 initial(Mr,Mrs...)별로 구분해서 보자.
sns.factorplot('Pclass', 'Survived', col = 'Initial', data = data)
plt.show()

# %% [markdown]
# 여성과 아이는 모든 클래스에서 생존률이 높다.

# %%
pd.crosstab([data.Embarked, data.Pclass],
            [data.Sex, data.Survived], margins = True).style.background_gradient(cmap = 'summer_r')
# Out:
# <style  type="text/css" >
# #T_48639818_bddf_11eb_a413_7c04d0c2b56erow0_col0,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow1_col2{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow0_col1{
#             background-color:  #d2e866;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow0_col2{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow0_col3{
#             background-color:  #d8ec66;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow0_col4,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow2_col3{
#             background-color:  #e8f466;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow1_col0,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow3_col0,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow3_col1,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow3_col2,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow3_col3,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow3_col4,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow4_col0,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow4_col2,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow4_col3,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow4_col4{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow1_col1,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow6_col0{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow1_col3,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow1_col4{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow2_col0,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow5_col1{
#             background-color:  #e6f266;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow2_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow2_col2{
#             background-color:  #eef666;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow2_col4,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow7_col0{
#             background-color:  #edf666;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow4_col1{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow5_col0{
#             background-color:  #e3f166;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow5_col2{
#             background-color:  #ecf666;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow5_col3{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow5_col4{
#             background-color:  #ebf566;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow6_col1{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow6_col2{
#             background-color:  #e4f266;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow6_col3{
#             background-color:  #bede66;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow6_col4{
#             background-color:  #dbed66;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow7_col1{
#             background-color:  #bdde66;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow7_col2{
#             background-color:  #d3e966;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow7_col3,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow8_col1{
#             background-color:  #dcee66;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow7_col4{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow8_col0{
#             background-color:  #52a866;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow8_col2{
#             background-color:  #81c066;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow8_col3{
#             background-color:  #b0d866;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow8_col4{
#             background-color:  #9acc66;
#             color:  #000000;
#         }#T_48639818_bddf_11eb_a413_7c04d0c2b56erow9_col0,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow9_col1,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow9_col2,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow9_col3,#T_48639818_bddf_11eb_a413_7c04d0c2b56erow9_col4{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_48639818_bddf_11eb_a413_7c04d0c2b56e" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan=2>female</th>        <th class="col_heading level0 col2" colspan=2>male</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Survived</th>        <th class="col_heading level1 col0" >0</th>        <th class="col_heading level1 col1" >1</th>        <th class="col_heading level1 col2" >0</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" ></th>    </tr>    <tr>        <th class="index_name level0" >Embarked</th>        <th class="index_name level1" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_48639818_bddf_11eb_a413_7c04d0c2b56elevel0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#                         <th id="T_48639818_bddf_11eb_a413_7c04d0c2b56elevel1_row0" class="row_heading level1 row0" >1</th>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow0_col1" class="data row0 col1" >42</td>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow0_col2" class="data row0 col2" >25</td>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow0_col3" class="data row0 col3" >17</td>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow0_col4" class="data row0 col4" >85</td>
#             </tr>
#             <tr>
#                                 <th id="T_48639818_bddf_11eb_a413_7c04d0c2b56elevel1_row1" class="row_heading level1 row1" >2</th>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow1_col1" class="data row1 col1" >7</td>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow1_col2" class="data row1 col2" >8</td>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow1_col3" class="data row1 col3" >2</td>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow1_col4" class="data row1 col4" >17</td>
#             </tr>
#             <tr>
#                                 <th id="T_48639818_bddf_11eb_a413_7c04d0c2b56elevel1_row2" class="row_heading level1 row2" >3</th>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow2_col0" class="data row2 col0" >8</td>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow2_col1" class="data row2 col1" >15</td>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow2_col2" class="data row2 col2" >33</td>
#                         <td id="T_48639818_bddf_11eb_a413_7c04d0c2b56erow2_col3" class="d

# %% [markdown]
# ## Chances for Survival by Port Of Embarkation (탑승 항구 별 생존률)

# %%
sns.factorplot('Embarked', 'Survived', data = data)
fig = plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %% [markdown]
# C 항구의 생존률이 약 0.55 정도로 가장 높고 S의 생존률이 가장 낮다.

# %%
f,ax = plt.subplots(2,2,figsize = (20,15))
sns.countplot('Embarked', data = data, ax = ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked', hue = 'Sex', data= data, ax = ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked', hue = 'Survived', data = data, ax = ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked', hue = 'Pclass', data = data, ax = ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2, hspace = 0.5)
plt.show()

# %% [markdown]
# 1. S 항구에 탑승한 승객이 가장 많다. 대부분은 Pclass 3 승객이다.
# 2. C 항구에 탑승한 승객은 생존률이 높다.  이유는 Pclass1 승객이 많아서 인 것 같다.
# 3. S 항구는 Pclass1의 승객이 많이 탔음에도 불구하고 생존률이 낮다. 이유는 Pclass3 또한 많이 탔기 때문이다.
# 4. Q 항구는 대부분 Pclass3 승객이다.

# %%
# Embarked(항구)와 성별에 따른 생존률을 알아보자. 
# col = 'Embarked' 사용해서 항구별로 그래프 나오게 하기
sns.factorplot('Pclass', 'Survived', hue = 'Sex', col = 'Embarked', data = data)

# %% [markdown]
# 1. 모든 항구에서 여성의 생존률이 훨씬 높다.
# 2. 여성의 생존률은 다른 Pclass 에 비해 Pclass3 에서 낮게 나타난다.
# 3. S 항구에서 탑승한 Pclass3 의 승객은 가장 생존률이 낮게 나타난다.

# %% [markdown]
# ## Filling Embarked NaN
# - Embarked 의 NaN 채우기. 대부분의 탑승객이 S 항구에서 탔으므로 S 로 채운다

# %%
#data['Embarked'].isnull().sum()
data['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
data['Embarked'].fillna('S', inplace = True)

# %%
data.Embarked.isnull().any() # NaN 모두 제거 되었는지 확인
# Out:
# False

# %% [markdown]
# ## SibSp → Discrete Feature
# 이 Feature는 탑승객이 혼자인지 아니면 가족과 함께 탔는지를 나타냅니다.
#
# Sibling → 형제자매, 의붓형제자매
#
# Spouse → 배우자

# %%
pd.crosstab([data.SibSp], data.Survived).style.background_gradient(cmap = 'summer_r')
# Out:
# <style  type="text/css" >
# #T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow0_col0,#T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow0_col1{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow1_col0{
#             background-color:  #c4e266;
#             color:  #000000;
#         }#T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow1_col1{
#             background-color:  #77bb66;
#             color:  #000000;
#         }#T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow2_col0,#T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow4_col0{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow2_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow3_col0,#T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow3_col1{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow4_col1{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow5_col0,#T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow5_col1,#T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow6_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow6_col0{
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56e" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow0_col0" class="data row0 col0" >398</td>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow0_col1" class="data row0 col1" >210</td>
#             </tr>
#             <tr>
#                         <th id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56elevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow1_col0" class="data row1 col0" >97</td>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow1_col1" class="data row1 col1" >112</td>
#             </tr>
#             <tr>
#                         <th id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56elevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow2_col0" class="data row2 col0" >15</td>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow2_col1" class="data row2 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56elevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow3_col0" class="data row3 col0" >12</td>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow3_col1" class="data row3 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56elevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow4_col0" class="data row4 col0" >15</td>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow4_col1" class="data row4 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56elevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow5_col0" class="data row5 col0" >5</td>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56elevel0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow6_col0" class="data row6 col0" >7</td>
#                         <td id="T_4a009c98_bddf_11eb_a413_7c04d0c2b56erow6_col1" class="data row6 col1" >0</td>
#             </tr>
#     </tbody></table>

# %%
f, ax = plt.subplots(1, 2, figsize=(15,6))

sns.barplot('SibSp', 'Survived', data=data, ax=ax[0])
ax[0].set_title('SibSp vs Survived')

sns.factorplot('SibSp', 'Survived', data=data, ax=ax[1])
ax[1].set_title('SibSp vs Survived')

#plt.close()
plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow0_col0,#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow0_col1,#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow0_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow1_col0{
#             background-color:  #7bbd66;
#             color:  #000000;
#         }#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow1_col1{
#             background-color:  #8ac466;
#             color:  #000000;
#         }#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow1_col2{
#             background-color:  #c6e266;
#             color:  #000000;
#         }#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow2_col0,#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow4_col2{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow2_col1{
#             background-color:  #eef666;
#             color:  #000000;
#         }#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow2_col2{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow3_col0,#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow3_col2{
#             background-color:  #fafc66;
#             color:  #000000;
#         }#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow3_col1{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow4_col0,#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow4_col1,#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow5_col0,#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow5_col1,#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow5_col2,#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow6_col0,#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow6_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow6_col2{
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56e" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow0_col0" class="data row0 col0" >137</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow0_col1" class="data row0 col1" >120</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow0_col2" class="data row0 col2" >351</td>
#             </tr>
#             <tr>
#                         <th id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56elevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow1_col0" class="data row1 col0" >71</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow1_col1" class="data row1 col1" >55</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow1_col2" class="data row1 col2" >83</td>
#             </tr>
#             <tr>
#                         <th id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56elevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow2_col0" class="data row2 col0" >5</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow2_col1" class="data row2 col1" >8</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow2_col2" class="data row2 col2" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56elevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow3_col0" class="data row3 col0" >3</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow3_col1" class="data row3 col1" >1</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow3_col2" class="data row3 col2" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56elevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow4_col0" class="data row4 col0" >0</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow4_col1" class="data row4 col1" >0</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow4_col2" class="data row4 col2" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56elevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow5_col0" class="data row5 col0" >0</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow5_col1" class="data row5 col1" >0</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56elevel0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow6_col0" class="data row6 col0" >0</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow6_col1" class="data row6 col1" >0</td>
#                         <td id="T_4ab7e600_bddf_11eb_a413_7c04d0c2b56erow6_col2" class="data row6 col2" >7</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# 1. barplot 을 보면 형제, 자매, 배우자가 없는 경우 생존률이 35% 정도 인 것을 볼 수 있다.
# 2. 가족 수가 증가할수록 그래프의 기울기가 감소하는 것을 볼 수 있다.
# 3. 가족이 있다면 서로를 살리기 위해 희생하기 때문에 이와 같은 결과라고 볼 수 있다.
# 4. 하지만 가족이 5-8 인 승객의 생존률은 0% 인 것을 볼 수있다.
# 5. croostab을 보면 SibSp > 3 인 승객은 모두 Pclass3 에 탑승했기 때문에 이러한 결과가 나왔다고 볼 수 있다.

# %% [markdown]
# ## Parch

# %%
pd.crosstab(data.Parch, data.Pclass).style.background_gradient(cmap = 'summer_r')
# Out:
# <style  type="text/css" >
# #T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow0_col0,#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow0_col1,#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow0_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow1_col0{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow1_col1{
#             background-color:  #c2e066;
#             color:  #000000;
#         }#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow1_col2{
#             background-color:  #dbed66;
#             color:  #000000;
#         }#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow2_col0{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow2_col1{
#             background-color:  #e1f066;
#             color:  #000000;
#         }#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow2_col2{
#             background-color:  #e3f166;
#             color:  #000000;
#         }#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow3_col0,#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow4_col1,#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow5_col0,#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow5_col1,#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow6_col0,#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow6_col1,#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow6_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow3_col1{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow3_col2,#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow4_col0,#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow4_col2{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow5_col2{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }</style><table id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56e" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >Parch</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow0_col0" class="data row0 col0" >163</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow0_col1" class="data row0 col1" >134</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow0_col2" class="data row0 col2" >381</td>
#             </tr>
#             <tr>
#                         <th id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56elevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow1_col0" class="data row1 col0" >31</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow1_col1" class="data row1 col1" >32</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow1_col2" class="data row1 col2" >55</td>
#             </tr>
#             <tr>
#                         <th id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56elevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow2_col0" class="data row2 col0" >21</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow2_col1" class="data row2 col1" >16</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow2_col2" class="data row2 col2" >43</td>
#             </tr>
#             <tr>
#                         <th id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56elevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow3_col0" class="data row3 col0" >0</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow3_col1" class="data row3 col1" >2</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow3_col2" class="data row3 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56elevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow4_col0" class="data row4 col0" >1</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow4_col1" class="data row4 col1" >0</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow4_col2" class="data row4 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56elevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow5_col0" class="data row5 col0" >0</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow5_col1" class="data row5 col1" >0</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56elevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow6_col0" class="data row6 col0" >0</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow6_col1" class="data row6 col1" >0</td>
#                         <td id="T_4abfdfe0_bddf_11eb_a413_7c04d0c2b56erow6_col2" class="data row6 col2" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# crosstab 은 가족 구성원이 많은 승객은 Pclass3 에 많이 탄 것을 보여준다.

# %%
f,ax = plt.subplots(1, 2, figsize = (20,8))
sns.barplot('Parch', 'Survived', data = data, ax = ax[0])
ax[0].set_title('Parch vs Survived')
sns.factorplot('Parch', 'Survived', data = data, ax = ax[1])
ax[1].set_title('Parch vs Survived')
plt.close(2)
plt.show()
# factorplot은 왜 안나와?
# plt.close 하는 이유?

# %% [markdown]
# ## Fare -> Continuous Featuers

# %%
print('Highest Fare was: ', data['Fare'].max())
print('Lowest Fare was: ', data['Fare'].min())
print('Average Fare was: ', data['Fare'].mean())
# Out:
# Highest Fare was:  512.3292
# Lowest Fare was:  0.0
# Average Fare was:  32.204207968574636

# %% [markdown]
# 가장 낮은 요금은 0 원 입니다.

# %%
f,ax = plt.subplots(1, 3, figsize = (20,8))
sns.distplot(data[data['Pclass']==1].Fare, ax = ax[0])
ax[0].set_title('Fares in Pclass1')
sns.distplot(data[data['Pclass']==2].Fare, ax = ax[1])
ax[1].set_title('Fares in Pclass2')
sns.distplot(data[data['Pclass']==3].Fare, ax = ax[2])
ax[2].set_title('Fares in Pclass3')
plt.show()

# %% [markdown]
# Pclass 1 탑승객의 경우 요금 분포가 넓게 퍼져있습니다. 그리고 Pclass 의 등급이 낮아질 때마다 분포가 좁아집니다. 이 변수는 연속형이기 때문에, 우리는 binning 을 통해 이산형 값들로 변환해줄 것입니다.

# %% [markdown]
# ## Feature 들의 관찰 결과 요약:
# - Sex : 남성보다 여성의 생존률이 높았다.
# - Pclass: Pclass 의 등급이 높을수록 생존률이 높고, Pclass3 의 생존률이 가장 낮았다.
# - Age: 어린 아이들의 생존 활률이 높았다.
# - Embarked: 항구 S 의 탑승객이 가장 많지만, 항구 C 의 생존률이 더 높게 나타났다.
# - Parch+SibSp: 혼자 탑승한 경우보다 1-2명의 자녀, 1-3명의 가족과 탑승한 승객의 생존률이 높았다.또한 많은 가족과 탑승한 경우 생존률이 낮았다.

# %% [markdown]
# ## Correlation Between The Features

# %%
sns.heatmap(data.corr(), annot = True, cmap = 'RdYlGn', linewidths = 0.2)
fig = plt.gcf()
fig.set_size_inches(20,10)
plt.show()

# %% [markdown]
# 두 Feature가 상당히 높은, 혹은 완전한 양의 상관관계를 가지고 있다고 하면, 한 feature값이 증가하면 다른 feature의 값도 증가합니다.
# 이것은 두 feature가 매우 비슷한 정보를 가지고 있으며, 그 정보간의 분산이 거의 없다는 것을 의미합니다. 이를 다중공선성(MultiColinearity)이라 합니다.
# 이 변수들이 redundant할 때, 우리는 그 변수를 둘 다 사용해야할까요?
# 모델을 만들거나 학습시킬 때, 학습시간을 줄이는 등 다른 이점을 위해 redudant한 feature는 제거되도록 해야합니다.
# 위의 Heatmap을 보았을 때, feature들간의 상관관계는 그렇게 높아보이지 않습니다.
# 가장 높은 상관관계를 지닌 두 변수는 SibSp와 Parch로 상관계수는 0.41입니다. 그렇기 때문에 모든 feature를 사용하도록 하겠습니다.

# %% [markdown]
# ## Part 2 : Feature Engineering and Data Cleansing

# %% [markdown]
# - Feature Engineering ?
# : 모든 feature가 중요하지 않기 때문에 dataset에서 제거되어야 할 feature를 알아보고, 새로운 feature를 만들기도 하는 것 이다.
#
# 즉, 예측 모델에 적합한 형태로 feature를 변환하는 것이다.

# %% [markdown]
# ## Age_band

# %%
data['Age_band'] = 0

data.loc[data['Age'] <= 16, 'Age_band'] = 0
data.loc[(data['Age'] > 16) & (data['Age'] <= 32), 'Age_band'] = 1
data.loc[(data['Age'] > 32) & (data['Age'] <= 48), 'Age_band'] = 2
data.loc[(data['Age'] > 48) & (data['Age'] <= 64), 'Age_band'] = 3
data.loc[data['Age'] > 64, 'Age_band'] = 4

data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0  A/5 21171   7.2500   NaN        S      Mr         1
# 1      0   PC 17599  71.2833   C85        C     Mrs         2

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')
# 각 연령 구간의 탑승객 수 체크
# Out:
# <style  type="text/css" >
# #T_4c4106c8_bddf_11eb_a413_7c04d0c2b56erow0_col0{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_4c4106c8_bddf_11eb_a413_7c04d0c2b56erow1_col0{
#             background-color:  #d8ec66;
#             color:  #000000;
#         }#T_4c4106c8_bddf_11eb_a413_7c04d0c2b56erow2_col0{
#             background-color:  #40a066;
#             color:  #000000;
#         }#T_4c4106c8_bddf_11eb_a413_7c04d0c2b56erow3_col0{
#             background-color:  #289366;
#             color:  #000000;
#         }#T_4c4106c8_bddf_11eb_a413_7c04d0c2b56erow4_col0{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_4c4106c8_bddf_11eb_a413_7c04d0c2b56e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age_band</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c4106c8_bddf_11eb_a413_7c04d0c2b56elevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_4c4106c8_bddf_11eb_a413_7c04d0c2b56erow0_col0" class="data row0 col0" >382</td>
#             </tr>
#             <tr>
#                         <th id="T_4c4106c8_bddf_11eb_a413_7c04d0c2b56elevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_4c4106c8_bddf_11eb_a413_7c04d0c2b56erow1_col0" class="data row1 col0" >325</td>
#             </tr>
#             <tr>
#                         <th id="T_4c4106c8_bddf_11eb_a413_7c04d0c2b56elevel0_row2" class="row_heading level0 row2" >0</th>
#                         <td id="T_4c4106c8_bddf_11eb_a413_7c04d0c2b56erow2_col0" class="data row2 col0" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_4c4106c8_bddf_11eb_a413_7c04d0c2b56elevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4c4106c8_bddf_11eb_a413_7c04d0c2b56erow3_col0" class="data row3 col0" >69</td>
#             </tr>
#             <tr>
#                         <th id="T_4c4106c8_bddf_11eb_a413_7c04d0c2b56elevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4c4106c8_bddf_11eb_a413_7c04d0c2b56erow4_col0" class="data row4 col0" >11</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Age_band', 'Survived', data=data, col = 'Pclass')
plt.show()

# %% [markdown]
# Pclass 와 상관없이 연령이 증가할수록 생존률은 낮아진다.

# %% [markdown]
# ## Family_Size 와 Alone
#
# 이번에는 "Family_Size"와 "Alone" Feature를 만들어 분석하겠습니다.
#
# 이 Feature들은 Parch와 SibSp의 요약입니다. 가족의 수와 생존률의 관계를 체크하기 위한 통합된 데이터를 얻을 수 있습니다.
#
# Alone은 승객이 혼자인지 아닌지를 나타냅니다.

# %%
data['Family_Size'] = 0
data['Family_Size'] = data['Parch'] + data['SibSp']
data['Alone'] = 0
data.loc[data.Family_Size == 0, 'Alone'] = 1

# %%
f, ax = plt.subplots(1, 2, figsize=(15,5))

sns.factorplot('Family_Size', 'Survived', data=data, ax=ax[0])
ax[0].set_title('Family_Size vs Survived')

sns.factorplot('Alone', 'Survived', data=data, ax=ax[1])
ax[1].set_title('Alone vs Survived')

#plt.close(2)
#plt.close(3)
plt.show()

# %% [markdown]
# Family_Size = 0 은 탑승객이 혼자임을 의미합니다. 혼자일 때, 생존률은 매우 낮습니다.
# 가족 수가 4명 이상일 때도 생존률은 감소합니다. 때문에 모델링에 중요한 Feature인 것 같습니다. 조금 더 분석해보겠습니다.

# %%
sns.factorplot('Alone', 'Survived', data=data, hue='Sex', col = 'Pclass')
plt.show()

# %% [markdown]
# Pclass와 무관하게 혼자 탑승한 경우는 위험합니다.
#
# 하지만 예외적으로 Pclass 3 여성 탑승객의 생존률은 가족과 함께 탑승하지 않은 경우보다 오히려 높습니다.

# %% [markdown]
# ## Fare_Range
#
# - Fare는 연속형 Feature이기 때문에, 이것을 서수형 값(Ordinal value)로 변환하겠습니다. 이 작업에pandas.qcut을 사용할 것입니다.
# - qcut 은 우리가 입력한 구간의 수(bin)에 따라 데이터 값을 분할 해줍니다. 가령 우리가 5개 구간을 입력하면, 5개의 구간으로 데이터 수를 균일하게 분할합니다.

# %%
data['Fare_Range'] = pd.qcut(data['Fare'], 4)
data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_4e89ea44_bddf_11eb_a413_7c04d0c2b56erow0_col0{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_4e89ea44_bddf_11eb_a413_7c04d0c2b56erow1_col0{
#             background-color:  #b9dc66;
#             color:  #000000;
#         }#T_4e89ea44_bddf_11eb_a413_7c04d0c2b56erow2_col0{
#             background-color:  #54aa66;
#             color:  #000000;
#         }#T_4e89ea44_bddf_11eb_a413_7c04d0c2b56erow3_col0{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_4e89ea44_bddf_11eb_a413_7c04d0c2b56e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Survived</th>    </tr>    <tr>        <th class="index_name level0" >Fare_Range</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4e89ea44_bddf_11eb_a413_7c04d0c2b56elevel0_row0" class="row_heading level0 row0" >(-0.001, 7.91]</th>
#                         <td id="T_4e89ea44_bddf_11eb_a413_7c04d0c2b56erow0_col0" class="data row0 col0" >0.197309</td>
#             </tr>
#             <tr>
#                         <th id="T_4e89ea44_bddf_11eb_a413_7c04d0c2b56elevel0_row1" class="row_heading level0 row1" >(7.91, 14.454]</th>
#                         <td id="T_4e89ea44_bddf_11eb_a413_7c04d0c2b56erow1_col0" class="data row1 col0" >0.303571</td>
#             </tr>
#             <tr>
#                         <th id="T_4e89ea44_bddf_11eb_a413_7c04d0c2b56elevel0_row2" class="row_heading level0 row2" >(14.454, 31.0]</th>
#                         <td id="T_4e89ea44_bddf_11eb_a413_7c04d0c2b56erow2_col0" class="data row2 col0" >0.454955</td>
#             </tr>
#             <tr>
#                         <th id="T_4e89ea44_bddf_11eb_a413_7c04d0c2b56elevel0_row3" class="row_heading level0 row3" >(31.0, 512.329]</th>
#                         <td id="T_4e89ea44_bddf_11eb_a413_7c04d0c2b56erow3_col0" class="data row3 col0" >0.581081</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# 위에서 얘기한 것처럼, Fare_Range가 증가할 수록 생존률도 증가합니다.
#
# 하지만 우리는 Fare_Range를 그대로 사용할 수 없습니다. Age_Band에서 했던 것과 동일하게 하나의 값으로 변환해주어야 합니다.

# %%
data['Fare_cat'] = 0
data.loc[data['Fare'] <= 7.91, 'Fare_cat'] = 0
data.loc[(data['Fare'] > 7.91) & (data['Fare']<=14.454), 'Fare_cat'] = 1
data.loc[(data['Fare'] > 14.454) & (data['Fare']<=31), 'Fare_cat'] = 2
data.loc[(data['Fare'] > 31) & (data['Fare']<=513), 'Fare_cat'] = 3

# %%
sns.factorplot('Fare_cat', 'Survived', data=data, hue='Sex')
plt.show()

# %% [markdown]
# Fare_cat 이 증가할수록 생존률이 증가합니다. 이것도 Sex와 함께 모델링에 중요한 Feature가 될 것 같습니다.

# %% [markdown]
# ## 문자열 값을 숫자형으로 변환하기
#
# 문자열 값을 머신러닝 모델에 사용할 수 없기 때문에, Sex, Embarked 등의 feature를 숫자값으로 변환해주어야 합니다.

# %%
data['Sex'].replace(['male','female'], [0, 1], inplace=True)
data['Embarked'].replace(['S','C','Q'],[0,1,2], inplace=True)
data['Initial'].replace(['Mr','Mrs','Miss','Master','Other'], [0,1,2,3,4], inplace=True)

# %%
data.head()
#data.info()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked  Initial  Age_band  Family_Size  \
# 0         A/5 21171   7.2500   NaN         0        0         1            1
# 1          PC 17599  71.2833   C85         1        1         2            1
# 2  STON/O2. 3101282   7.9250   NaN         0        2         1            0
# 3            113803  53.1000  C123         0        1         2            1
# 4            373450   8.0500   NaN         0        0         2            0
#
#    Alone       Fare_Range  Fare_cat
# 0      0   (-0.001, 7.91]         0
# 1      0  (31.0, 512.329]         3
# 2      1   (7.91, 14.454]         1
# 3      0  (31.0, 512.329]         3
# 4      1   (7.91, 14.454]         1

# %% [markdown]
# ## 필요하지 않은 Feature를 drop하기
# - Name → Categorical value로 변환할 수 없으므로 필요 없습니다.
# - Age → Age_band가 있기 때문에 필요 없습니다.
# - Ticket → 카테고리화 될 수 없는 무작위 문자열입니다.
# - Fare → Fare_cat이 있기 때문에 필요없습니다.
# - Cabin → NaN 값이 너무 많고, 많은 승객에 따라 cabin 값이 많습니다. 그렇기 때문에 필요하지 않습니다.
# - Fare_Range → Fare_cat이 있어서 필요 없습니다.
# - PassengerId → 카테고리화 될 수 없습니다.

# %%
data.drop(['Name', 'Age', 'Ticket', 'Fare', 'Cabin', 
           'Fare_Range', 'PassengerId'], axis=1, inplace=True)

sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', linewidths=0.2, annot_kws={'size' : 20})
fig = plt.gcf()
fig.set_size_inches(15, 15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# 위의 Correlation plot에서 몇몇 양의 상관관계를 가진 feature들을 볼 수 있습니다.
#
# SibSp, Family_Size와 Parch 가 양의 상관관계를 가지고, Alone과 Family_Size는 음의 상관관계를 가지고 있습니다.
